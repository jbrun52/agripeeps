# %%
from enum import Enum
from pathlib import Path
import pandas as pd 
import logging
logging.basicConfig(level=logging.INFO, format='%(levelname)s: %(message)s')

# %%
def assert_climate(wet_climate :str):
    # If wet_climate is None, set climate_key to 'default'
    if wet_climate is None:
        climate_key = 'default'
    else:
        # Ensure wet_climate is either 'wet' or 'dry'
        if wet_climate not in ['wet', 'dry']:
            logging.error(f"Invalid wet_climate value: {wet_climate}. Expected 'wet', 'dry', or None.")
            return None  # Return None in case of an error
        climate_key = wet_climate
        
    return climate_key

# %%
def get_emission_factors(
    climate_key = 'default',
):
    df_emission_factors = pd.read_csv("../docs/EF.csv", sep=';')
    emission_factors_filtered = df_emission_factors[df_emission_factors['climate_type'] == climate_key]

    return emission_factors_filtered

# %%
df_emission_factors = pd.read_csv("../docs/EF.csv", sep = ';')

# %%
df_emission_factors
# Out:
#                                          crop_iri  \
# 0   http://data.europa.eu/xsp/cn2024/060011000090
# 1   http://data.europa.eu/xsp/cn2024/060011000090
# 2   http://data.europa.eu/xsp/cn2024/060011000090
# 3   http://data.europa.eu/xsp/cn2024/060011000090
# 4   http://data.europa.eu/xsp/cn2024/060011000090
# 5   http://data.europa.eu/xsp/cn2024/060011000090
# 6   http://data.europa.eu/xsp/cn2024/100600000080
# 7   http://data.europa.eu/xsp/cn2024/100600000080
# 8   http://data.europa.eu/xsp/cn2024/100600000080
# 9   http://data.europa.eu/xsp/cn2024/060011000090
# 10  http://data.europa.eu/xsp/cn2024/060011000090
# 11  http://data.europa.eu/xsp/cn2024/060011000090
# 12  http://data.europa.eu/xsp/cn2024/060011000090
# 13  http://data.europa.eu/xsp/cn2024/060011000090
# 14  http://data.europa.eu/xsp/cn2024/060011000090
# 15  http://data.europa.eu/xsp/cn2024/060011000090
# 16  http://data.europa.eu/xsp/cn2024/060011000090
# 17  http://data.europa.eu/xsp/cn2024/060011000090
#
#                                          fert_iri  climate_type  fert_type  \
# 0   http://data.europa.eu/xsp/cn2024/310200000080           dry    default
# 1   http://data.europa.eu/xsp/cn2024/310200000080           dry    default
# 2   http://data.europa.eu/xsp/cn2024/310200000080           dry    default
# 3   http://data.europa.eu/xsp/cn2024/310200000080       default    default
# 4   http://data.europa.eu/xsp/cn2024/310200000080       default    default
# 5   http://data.europa.eu/xsp/cn2024/310200000080       default    default
# 6   http://data.europa.eu/xsp/cn2024/310200000080  flooded_rice    default
# 7   http://data.europa.eu/xsp/cn2024/310200000080  flooded_rice    default
# 8   http://data.europa.eu/xsp/cn2024/310200000080  flooded_rice    default
# 9   http://data.europa.eu/xsp/cn2024/310200000080           wet  inorganic
# 10  http://data.europa.eu/xsp/cn2024/310200000080           wet  inorganic
# 11  http://data.europa.eu/xsp/cn2024/310200000080           wet  inorganic
# 12  http://data.europa.eu/xsp/cn2024/310200000080           wet    organic
# 13  http://data.europa.eu/xsp/cn2024/310200000080           wet    organic
# 14  http://data.europa.eu/xsp/cn2024/310200000080           wet    organic
# 15  http://data.europa.eu/xsp/cn2024/310200000080           wet   residual
# 16  http://data.europa.eu/xsp/cn2024/310200000080           wet   residual
# 17  http://data.europa.eu/xsp/cn2024/310200000080           wet   residual
#
#    value_type  emission_factor
# 0       value            0.005
# 1         min            0.000
# 2         max            0.011
# 3       value            0.010
# 4         min            0.001
# 5         max            0.018
# 6       value            0.004
# 7         min            0.000
# 8         max            0.029
# 9       value            0.016
# 10        min            0.013
# 11        max            0.019
# 12      value            0.006
# 13        min            0.001
# 14        max            0.011
# 15      value            0.006
# 16        min            0.001
# 17        max            0.011

# %%
climate_key = 'default'

# %%
emission_factors_filtered = df_emission_factors[df_emission_factors['climate_type'] == climate_key]

# %%
emission_factors_filtered
# Out:
#                                         crop_iri  \
# 3  http://data.europa.eu/xsp/cn2024/060011000090
# 4  http://data.europa.eu/xsp/cn2024/060011000090
# 5  http://data.europa.eu/xsp/cn2024/060011000090
#
#                                         fert_iri climate_type fert_type  \
# 3  http://data.europa.eu/xsp/cn2024/310200000080      default   default
# 4  http://data.europa.eu/xsp/cn2024/310200000080      default   default
# 5  http://data.europa.eu/xsp/cn2024/310200000080      default   default
#
#   value_type  emission_factor
# 3      value            0.010
# 4        min            0.001
# 5        max            0.018

# %%
df = get_emission_factors()

# %%
df
# Out:
#                                         crop_iri  \
# 3  http://data.europa.eu/xsp/cn2024/060011000090
# 4  http://data.europa.eu/xsp/cn2024/060011000090
# 5  http://data.europa.eu/xsp/cn2024/060011000090
#
#                                         fert_iri climate_type fert_type  \
# 3  http://data.europa.eu/xsp/cn2024/310200000080      default   default
# 4  http://data.europa.eu/xsp/cn2024/310200000080      default   default
# 5  http://data.europa.eu/xsp/cn2024/310200000080      default   default
#
#   value_type  emission_factor
# 3      value            0.010
# 4        min            0.001
# 5        max            0.018

# %%
def get_emission(emission_factor : pd.DataFrame(), N_total:float):
    emission_factor['emission [kg_N20/ha]'] = emission_factor.apply(lambda x : x['emission_factor']*(28+16)/28*N_total , axis = 1)
    return emission_factor

# %%
df = get_emission(df, 8)

# %%
print(df)
# Out:
#                                         crop_iri  \
# 3  http://data.europa.eu/xsp/cn2024/060011000090
# 4  http://data.europa.eu/xsp/cn2024/060011000090
# 5  http://data.europa.eu/xsp/cn2024/060011000090
#
#                                         fert_iri climate_type fert_type  \
# 3  http://data.europa.eu/xsp/cn2024/310200000080      default   default
# 4  http://data.europa.eu/xsp/cn2024/310200000080      default   default
# 5  http://data.europa.eu/xsp/cn2024/310200000080      default   default
#
#   value_type  emission_factor  emission [kg_N20/ha]
# 3      value            0.010              0.125714
# 4        min            0.001              0.012571
# 5        max            0.018              0.226286

# %%
def _run(N_total: float, wet_climate: str = None):
    climate_key = assert_climate(wet_climate)
    emission_factors = get_emission_factors(climate_key)
    df_emission = get_emission(emission_factors, N_total)

    logging.info(df_emission)
    return df_emission

# wet_climate = "wet", "dry", None
def run(fertilizer_n_per_ha, climate: str = None):
    return _run(fertilizer_n_per_ha, climate)

# %%
run(7)
# Out:
# INFO:                                         crop_iri  \
# 3  http://data.europa.eu/xsp/cn2024/060011000090
# 4  http://data.europa.eu/xsp/cn2024/060011000090
# 5  http://data.europa.eu/xsp/cn2024/060011000090
#
#                                         fert_iri climate_type fert_type  \
# 3  http://data.europa.eu/xsp/cn2024/310200000080      default   default
# 4  http://data.europa.eu/xsp/cn2024/310200000080      default   default
# 5  http://data.europa.eu/xsp/cn2024/310200000080      default   default
#
#   value_type  emission_factor  emission [kg_N20/ha]
# 3      value            0.010                 0.110
# 4        min            0.001                 0.011
# 5        max            0.018                 0.198
#                                         crop_iri  \
# 3  http://data.europa.eu/xsp/cn2024/060011000090
# 4  http://data.europa.eu/xsp/cn2024/060011000090
# 5  http://data.europa.eu/xsp/cn2024/060011000090
#
#                                         fert_iri climate_type fert_type  \
# 3  http://data.europa.eu/xsp/cn2024/310200000080      default   default
# 4  http://data.europa.eu/xsp/cn2024/310200000080      default   default
# 5  http://data.europa.eu/xsp/cn2024/310200000080      default   default
#
#   value_type  emission_factor  emission [kg_N20/ha]
# 3      value            0.010                 0.110
# 4        min            0.001                 0.011
# 5        max            0.018                 0.198
