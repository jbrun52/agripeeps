# %%
from agripeeps.n2OToAirInorganicFertiliserDirect import run

run(1,"wet")
# Out:
# [{'value': [0.025142857142857144],
#   'min': [0.020428571428571428],
#   'max': [0.029857142857142856],
#   'sd': [0.002357142857142857],
#   'methodModelDescription': 'Disaggregated version'}]

# %%
import pandas as pd

df = pd.DataFrame.from_dict(N2O_FACTORS)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 import pandas as pd
# ----> 3 df = pd.DataFrame.from_dict(N2O_FACTORS)
#
# NameError: name 'N2O_FACTORS' is not defined

# %%
df_fertiliser_last = pd.read_csv("https://raw.githubusercontent.com/ludemannc/FUBC_1_to_9_2022/refs/heads/main/results/FUBC_9_unaggregated_crop_data.csv")

crop_lookup = df_fertiliser_last[["Crop", "Crop_UNFAO_aggregated"]].set_index("Crop").to_dict()['Crop_UNFAO_aggregated']
crop_lookup
# Out:
# {'Wheat': 'Wheat',
#  'Rice': 'Rice, paddy',
#  'Other cereals': 'Other cereals',
#  'Barley': 'Barley',
#  'Sorghum': 'Sorghum',
#  'Soybeans': 'Soybeans',
#  'Other oilseeds': 'Other oil Crops',
#  'Sunflowers': 'Sunflower seed',
#  'Cotton': 'Cottonseed',
#  'Sugarcane': 'Sugar cane',
#  'Roots & Tubers': 'Roots and tubers nes',
#  'Potatoe': 'Potato',
#  'Fruits': 'Fruit primary and citrus fruits and treenuts',
#  'Citrus': 'Fruit primary and citrus fruits and treenuts',
#  'Vineyards + Raisins': 'Fruit primary and citrus fruits and treenuts',
#  'Vegetables': 'Vegetables, fresh nes',
#  'Pastures': 'Grassland',
#  'Tobacco': 'Tobacco, unmanufactured',
#  'Residual': 'Residual',
#  'Maize': 'Maize',
#  'Fruit Primary': 'Fruit primary and citrus fruits and treenuts',
#  'Other Oil Crops': 'Other oil Crops',
#  'Rice, paddy': 'Rice, paddy',
#  'Seed cotton': 'Cottonseed',
#  'Sugar cane': 'Sugar cane',
#  'Grassland': 'Grassland',
#  'Grain maize, including corn cob maize': 'Maize',
#  'Green maize': 'Maize, green',
#  'Oilseed rape': 'Rapeseed',
#  'Other oil crops': 'Other oil Crops',
#  'Sugar beet': 'Sugar beet',
#  'Fruits & Treenuts': 'Fruit primary and citrus fruits and treenuts',
#  'Pulses (peas, beans)': 'Pulses',
#  'Potato': 'Potato',
#  'Total Grassland': 'Grassland',
#  'Fertilized forests': 'Forestry',
#  'Other crops': 'Other crops',
#  'Roots and Tubers, Total': 'Roots and tubers nes',
#  'Vegetables Primary': 'Vegetables, fresh nes',
#  'Maize, Green (silage, bioenergy)': 'Maize, green',
#  'Other Cereals': 'Other cereals',
#  'Rapeseed / Canola': 'Rapeseed',
#  'Sugar Beet': 'Sugar beet',
#  'Roots & Tubers (potato)': 'Potato',
#  'Pulses': 'Pulses',
#  'Grassland (grasses and meadows and pastures)': 'Grassland',
#  'Flax (fiber)': 'Flax fibre and tow',
#  'Oil Palm': 'Oil palm fruit',
#  'Sugar Cane': 'Sugar cane',
#  'Tea': 'Tea',
#  'Coffee': 'Coffee, green',
#  'Cocoa': 'Cocoa, beans',
#  'Maize Grain': 'Maize',
#  'Forages': 'Grassland',
#  'Grain Maize': 'Maize',
#  'Green Maize (silage, bioenergy)': 'Maize, green',
#  'Orange': 'Fruit primary and citrus fruits and treenuts',
#  'Commercial Forests': 'Forestry',
#  'Millet': 'Millet',
#  'Cow pea': 'Pulses',
#  'Fruits and vegetables': 'Vegetables, fresh nes',
#  'Roots and Tubers': 'Roots and tubers nes',
#  'Treenuts': 'Fruit primary and citrus fruits and treenuts',
#  'Other pulses': 'Pulses',
#  'Green Maize': 'Maize, green',
#  'Rapeseed/Canola': 'Rapeseed',
#  'Sugar, Total (Beet)': 'Sugar beet',
#  'Tame Hay': 'Grassland',
#  'Grassland (intensive)': 'Grassland',
#  'Maize, Total': 'Maize',
#  'Fruits (apples, citrus, oranges)': 'Fruit primary and citrus fruits and treenuts',
#  'Sugar beet and sugar cane': 'Sugar crops nes',
#  'Maize, Grain': 'Maize',
#  'Jute': 'Jute',
#  'Oil palm': 'Oil palm fruit',
#  'non irrigated winter crops (mainly wheat)': 'Wheat',
#  'irrigated field crops': 'Other cereals',
#  'open field vegetables': 'Vegetables, fresh nes',
#  'covered vegetables': 'Vegetables, fresh nes',
#  'orchards': 'Fruit primary and citrus fruits and treenuts',
#  'citrus': 'Fruit primary and citrus fruits and treenuts',
#  'non irrigated olives': 'Other oil Crops',
#  'irrigated olives': 'Other oil Crops',
#  'flowers': 'flowers',
#  'fresh herbs': 'fresh herbs',
#  'Maize, green': 'Maize, green',
#  'vegetables': 'Vegetables, fresh nes',
#  'Olives': 'Other oil Crops',
#  'Roots and tubers': 'Roots and tubers nes',
#  'Maize (Green)': 'Maize (Green)',
#  'Fruits & Tree-nuts': 'Fruit primary and citrus fruits and treenuts',
#  'Flowers': 'Flowers',
#  'Mil - Sorghum': 'Sorghum',
#  'Treenuts, Total': 'Fruit primary and citrus fruits and treenuts',
#  'Sugar cane and Sugar beet': 'Sugar beet',
#  'Oth Cereals': 'Other cereals',
#  'Oth Oilseeds': 'Other oil Crops',
#  'Sugar beet and Sugar cane': 'Sugar crops nes',
#  'Roots/Tubers': 'Roots and tubers nes',
#  'Roots & Tubers (Potato)': 'Potato',
#  'Other Crop 1 (Garlic)': 'Garlic',
#  'Other Crop 2 (Onion)': 'Onion',
#  'Grassland (Dairy)': 'Grassland',
#  'Grassland (Sheep & Beef )': 'Grassland',
#  'Grassland (Deer)': 'Grassland',
#  'Grain and other crops': 'Other cereals',
#  'Grain mixed sheep & Beef': 'Other cereals',
#  'Vegetables (including root & tuber veg)': 'Vegetables, fresh nes',
#  'Forestry': 'Forestry',
#  'Amenity Horticulture': 'Amenity Horticulture',
#  'RIce': 'Rice, paddy',
#  'Soybean': 'Soybeans',
#  'Cassava': 'Cassava',
#  'Yam': 'Yam',
#  'Cocoyam / Taro': 'Roots and tubers nes',
#  'Ginger': 'Ginger',
#  'Ground nut': 'Ground nut',
#  'Fruits and treenuts': 'Fruit primary and citrus fruits and treenuts',
#  'Vegetables6': 'Vegetables, fresh nes',
#  'Rangeland': 'Grassland',
#  'Cultivated Pastures': 'Grassland',
#  'Coconut': 'Other oil Crops',
#  'Peanut': 'Peanut',
#  'Niebe': 'Pulses',
#  'Sesame': 'Sesame',
#  'Fonio': 'Millet',
#  'Horticulture': 'Horticulture',
#  'Tomato - Industrial': 'Tomato',
#  'Citrus Fruit, Total': 'Fruit primary and citrus fruits and treenuts',
#  'Vineyards': 'Fruit primary and citrus fruits and treenuts',
#  'Lucerne': 'Grassland',
#  'Maize grain': 'Maize',
#  'Irish potatos': 'Potato',
#  'Beans': 'Beans',
#  'Tobacco - flue-cured': 'Tobacco, unmanufactured',
#  'Tobacco - fire-cured': 'Tobacco, unmanufactured',
#  'Other cereals & oil seeds': 'Other cereals',
#  'Pulses, Total': 'Pulses',
#  'Cocoa, beans': 'Cocoa, beans',
#  'Other Oil Crops (Coconut)': 'Other oil Crops',
#  'Fruits (Pineapple+Mangoe+Longan+Rambutan+Durian+Mangosteen+Lychee+Tangerine+Longkong+Lime) & Treenuts': 'Fruit primary and citrus fruits and treenuts',
#  'Vegetables (Garlic+Shallot+Onion+Potato+Tomato+Baby corn+Pepper)': 'Potato',
#  'Sweet corn': 'Sweet corn',
#  'Residual (rubber)': 'Rubber, natural',
#  'Maize for grain': 'Maize',
#  'Other cereal and leguminous crops': 'Other cereals',
#  'Soya beans': 'Soybeans',
#  'Rapeseed': 'Rapeseed',
#  'Sunflower seeds': 'Sunflower seed',
#  'Other industrial crops': 'Other industrial crops',
#  'Edible roots and tubers with high starch and inulin content': 'Roots and tubers nes',
#  'Vegetables grown in open-field, including for seed': 'Vegetables, fresh nes',
#  'Vegetables grown in greenhouses': 'Vegetables, fresh nes',
#  'Food melons, including for seed': 'Fruit primary and citrus fruits and treenuts',
#  'Fodder crops, including for seed': 'Grassland',
#  'Hayfields': 'Grassland',
#  'Cultivated pastures': 'Grassland',
#  'Perennial crops': 'Grassland'}

# %%
df = pd.read_csv("geonames.tsv", sep='\t')
lookup = df[["ISO3", "geonameid"]].set_index("ISO3").to_dict()['geonameid']

# %%
df_fertiliser = pd.read_csv("https://raw.githubusercontent.com/ludemannc/FUBC_1_to_9_2022/refs/heads/main/results/FUBC_1_to_9_data.csv")
df_fertiliser["geonameid"] = df_fertiliser.ISO3_code.apply(lambda code: lookup[code])
df_fertiliser
# Out:
#      Original_country_name_in_FUBC_report   Country ISO3_code Region_IFA  \
# 0                                 ALGERIA   Algeria       DZA     Africa
# 1                                 ALGERIA   Algeria       DZA     Africa
# 2                                 ALGERIA   Algeria       DZA     Africa
# 3                                 ALGERIA   Algeria       DZA     Africa
# 4                                 ALGERIA   Algeria       DZA     Africa
# ...                                   ...       ...       ...        ...
# 7524                              Vietnam  Viet Nam       VNM  East Asia
# 7525                              Vietnam  Viet Nam       VNM  East Asia
# 7526                              Vietnam  Viet Nam       VNM  East Asia
# 7527                              Vietnam  Viet Nam       VNM  East Asia
# 7528                              Vietnam  Viet Nam       VNM  East Asia
#
#       Year  FUBC_report_number  Year_FUBC_publication            Crop  \
# 0     1986                   1                   1992          Barley
# 1     1986                   1                   1992          carrot
# 2     1986                   1                   1992   citrus Fruits
# 3     1986                   1                   1992          Fallow
# 4     1986                   1                   1992  Fruits (Other)
# ...    ...                 ...                    ...             ...
# 7524  2018                   9                   2022            Rice
# 7525  2018                   9                   2022    Roots/tubers
# 7526  2018                   9                   2022        Soybeans
# 7527  2018                   9                   2022      Sugar cane
# 7528  2018                   9                   2022      Vegetables
#
#       Crop_area_k_ha       N_k_t  ...  P2O5_rate_kg_ha  K2O_rate_kg_ha  \
# 0           1212.000         NaN  ...              NaN             NaN
# 1             17.000    1.700000  ...            108.0           108.0
# 2             45.000   11.300000  ...             80.0           100.0
# 3           2900.000    0.000000  ...              0.0             0.0
# 4             34.000    3.400000  ...             80.0           100.0
# ...              ...         ...  ...              ...             ...
# 7524        7570.741  966.146670  ...              NaN             NaN
# 7525         655.627   30.872566  ...              NaN             NaN
# 7526          53.364    2.839606  ...              NaN             NaN
# 7527         269.434   58.751792  ...              NaN             NaN
# 7528        1009.363  112.822623  ...              NaN             NaN
#
#       N_pc_fert  P2O5_pc_fert  K2O_pc_fert  Aver_N_rate_kg_ha  \
# 0           NaN           NaN          NaN                NaN
# 1         100.0         100.0        100.0                NaN
# 2         100.0         100.0        100.0                NaN
# 3           0.0           0.0          0.0                NaN
# 4         100.0         100.0        100.0                NaN
# ...         ...           ...          ...                ...
# 7524        NaN           NaN          NaN         127.615866
# 7525        NaN           NaN          NaN          47.088614
# 7526        NaN           NaN          NaN          53.212015
# 7527        NaN           NaN          NaN         218.056339
# 7528        NaN           NaN          NaN         111.776063
#
#       Aver_P2O5_rate_kg_ha  Aver_K2O_rate_kg_ha  Aver_N_P2O5_K2O_rate_kg_ha  \
# 0                      NaN                  NaN                         NaN
# 1                      NaN                  NaN                         NaN
# 2                      NaN                  NaN                         NaN
# 3                      NaN                  NaN                         NaN
# 4                      NaN                  NaN                         NaN
# ...                    ...                  ...                         ...
# 7524             69.385810            38.724213                  235.725888
# 7525             12.001159            11.086089                   70.175861
# 7526             58.121952            35.793495                  147.127462
# 7527             76.415012           102.674159                  397.145510
# 7528             50.644647            38.985892                  201.406603
#
#       geonameid
# 0       2589581
# 1       2589581
# 2       2589581
# 3       2589581
# 4       2589581
# ...         ...
# 7524    1562822
# 7525    1562822
# 7526    1562822
# 7527    1562822
# 7528    1562822
#
# [7529 rows x 24 columns]

# %%
countries = df_fertiliser["ISO3_code"].unique()
years = df_fertiliser["Year"].str[0:4].unique()
years
# Out:
# array(['1986', '1991', '1990', '1989', '1987', '1988', '1984', '1993',
#        '1992', '1978', '1994', '1995', '1996', '1997', '1999', '1998',
#        '2000', '2001', '2006', '2007', '2010', '2014', '2018', '2017',
#        '2019', '2016'], dtype=object)

# %%
crops = df_fertiliser["ISO3_code"].unique()
crops

# %%
# %pip install faostat

# %%
crops = list(crop_lookup.keys())
for crop in ["Soybeans", "Other cereals", 'Other oilseeds', 'Sunflowers', 'Cotton', 'Sugarcane', 'Roots & Tubers', 'Potatoe']:
    crops.remove(crop)
crops
crops = ['Wheat',
 'Rice',
 'Barley',
 'Sorghum',
 'Maize (corn)']

# %%
import faostat

def get_FAO_data(dataset_code, element, items, list_year):
    element_values = faostat.get_par(dataset_code, "element")
    element_number = element_values[element]
    item_values = faostat.get_par(dataset_code, "items")
    #print(item_values)
    items_number = [item_values[item] for item in items]
    data = faostat.get_data_df(
        dataset_code,
        pars={"element": element_number,
              "item": items_number,
              "year": list_year},
        coding={"area_cs": "ISO3"}
    )
    return data

def get_FAO_mean(dataset_code, element, items, list_year):
    data = get_FAO_data(dataset_code, element, items, list_year)
    # average over years
    #display(data)
    data = data.astype({"Value": "float"}).groupby(["Area", "Item"])["Value"].agg('mean')
    #data.index.name = ["Countries", "Crop"]
    return data

def fao_yield():
    data = get_FAO_mean(
            dataset_code="QCL",
            element="Yield",
            items=crops,
            list_year=years,
        )
    data = data/1e4 #convert from 100g/ha to ton/ha
    return data

fao_yield()
# Out:
# Area         Item
# Afghanistan  Barley          0.115720
#              Maize (corn)    0.175537
#              Rice            0.261406
#              Wheat           0.136331
# Africa       Barley          0.106418
#                                ...
# Zimbabwe     Barley          0.535737
#              Maize (corn)    0.117496
#              Rice            0.163987
#              Sorghum         0.044798
#              Wheat           0.466201
# Name: Value, Length: 827, dtype: float64

# %%
# %pip install solara

# %%
import pathlib
import sys
from typing import Optional, cast
import os

import pandas as pd

import solara
import solara.express as solara_px  # similar to plotly express, but comes with cross filters
import solara.lab
from solara.components.columns import Columns
from solara.components.file_drop import FileDrop

github_url = solara.util.github_url(os.path.abspath('Untitled.ipynb'))
if sys.platform != "emscripten":
    pycafe_url = solara.util.pycafe_url(path=pathlib.Path(os.path.abspath('Untitled.ipynb')), requirements=["pandas", "plotly"])
else:
    pycafe_url = None
df_sample = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/gapminderDataFiveYear.csv")


class State:
    size_max = solara.reactive(40.0)
    size = solara.reactive(cast(Optional[str], None))
    color = solara.reactive(cast(Optional[str], None))
    x = solara.reactive(cast(Optional[str], None))
    y = solara.reactive(cast(Optional[str], None))
    logx = solara.reactive(False)
    logy = solara.reactive(False)
    df = solara.reactive(cast(Optional[pd.DataFrame], None))

    @staticmethod
    def load_sample():
        State.x.value = "gdpPercap"
        State.y.value = "lifeExp"
        State.size.value = "pop"
        State.color.value = "continent"
        State.logx.value = True
        State.df.value = df_sample

    @staticmethod
    def load_from_file(file):
        df = pd.read_csv(file["file_obj"])
        State.x.value = str(df.columns[0])
        State.y.value = str(df.columns[1])
        State.size.value = str(df.columns[2])
        State.color.value = str(df.columns[3])
        State.df.value = df

    @staticmethod
    def reset():
        State.df.value = None


@solara.component
def Page():
    df = State.df.value
    dark_effective = solara.lab.use_dark_effective()

    # the .scatter will set this cross filter
    filter, _set_filter = solara.use_cross_filter(id(df))

    # only apply the filter if the filter or dataframe changes
    def filter_df():
        if filter is not None and df is not None:
            return df.loc[filter]

    dff = solara.use_memo(filter_df, dependencies=[df, filter])

    with solara.AppBar():
        solara.lab.ThemeToggle()
    with solara.Sidebar():
        with solara.Card("Controls", margin=0, elevation=0):
            with solara.Column():
                with solara.Row():
                    solara.Button("Sample dataset", color="primary", text=True, outlined=True, on_click=State.load_sample, disabled=df is not None)
                    solara.Button("Clear dataset", color="primary", text=True, outlined=True, on_click=State.reset)
                if sys.platform != "emscripten":
                    FileDrop(on_file=State.load_from_file, on_total_progress=lambda *args: None, label="Drag file here")
                else:
                    solara.Info("File upload not supported in this environment")

                if df is not None:
                    solara.SliderFloat(label="Size", value=State.size_max, min=1, max=100)
                    solara.Checkbox(label="Log x", value=State.logx)
                    solara.Checkbox(label="Log y", value=State.logy)
                    columns = list(map(str, df.columns))
                    solara.Select("Column x", values=columns, value=State.x)
                    solara.Select("Column y", values=columns, value=State.y)
                    solara.Select("Size", values=columns, value=State.size)
                    solara.Select("Color", values=columns, value=State.color)
                    if filter is None:
                        solara.Info("If you select points in the scatter plot, you can download the points here.")
                    else:

                        def get_data():
                            return dff.to_csv(index=False)

                        solara.FileDownload(get_data, label=f"Download {len(dff):,} selected points", filename="selected.csv")

    if df is not None:
        with Columns(widths=[2, 4]):
            if State.x.value and State.y.value:
                solara_px.scatter(
                    df,
                    State.x.value,
                    State.y.value,
                    size=State.size.value,
                    color=State.color.value,
                    size_max=State.size_max.value,
                    log_x=State.logx.value,
                    log_y=State.logy.value,
                    template="plotly_dark" if dark_effective else "plotly_white",
                )
            else:
                solara.Warning("Select x and y columns")

    else:
        solara.Info("No data loaded, click on the sample dataset button to load a sample dataset, or upload a file.")

    with solara.Column(style={"max-width": "400px"}):
        solara.Button(label="View source", icon_name="mdi-github-circle", attributes={"href": github_url, "target": "_blank"}, text=True, outlined=True)
        if sys.platform != "emscripten":
            solara.Button(
                label="Edit this example live on py.cafe",
                icon_name="mdi-coffee-to-go-outline",
                attributes={"href": pycafe_url, "target": "_blank"},
                text=True,
                outlined=True,
            )


@solara.component
def Layout(children):
    route, routes = solara.use_route()
    dark_effective = solara.lab.use_dark_effective()
    return solara.AppLayout(children=children, toolbar_dark=dark_effective, color=None)  # if dark_effective else "primary")

Layout([Page()])
# Out:
# Cannot show ipywidgets in text
